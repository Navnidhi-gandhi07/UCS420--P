# %% [markdown]
# <a href="https://colab.research.google.com/github/Navnidhi-gandhi07/UCS420--P/blob/main/Assignment6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
M = float(input("Enter value  "))
x = np.linspace(-10,10,100)
y1 = M * x**2
y2 = M * np.sin(x)
# Out:
# Enter value  2

# %%
plt.figure(figsize=(6,6))
plt.plot(x,y1,label = 'M*x^2',color = 'green',linestyle = '-')
plt.plot(x,y2,label = 'M*sin(x)',color = 'red',linestyle = '--')
plt.legend()
plt.grid(True)
plt.title('Plot of y = M*x^2 and y = M*sin(x)')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()

# %%
data = {
    'Subjects' : ['DBMS','CC','DAA','PNS','AI'],
    'Scores' : [100,98,99,97,95]
}
df = pd.DataFrame(data)
plt.figure(figsize = (10,6))
colors = sns.color_palette('husl',len(df))
sns.barplot(x='Subjects',y='Scores',data=df,hue='Subjects',palette=colors,legend=False)

for i,score in enumerate(df['Scores']):
    plt.text(i,score+1,str(score),ha='center',fontsize=14)

plt.grid(axis='y',linestyle='--',alpha=0.6)
plt.title('Score Sheet of different Subjects')
plt.xlabel('Subjects')
plt.ylabel('Scores')
plt.show()

# %%
Roll = 102317298
np.random.seed(Roll)

data = np.random.randn(50)

fig,axes = plt.subplots(2,2,figsize=(10,10))

axes[0,0].plot(np.cumsum(data),color='red',linestyle='-',marker='o',markersize=4)
axes[0,0].set_title('Cumulative Sum Plot')
axes[0,0].set_xlabel('Index')
axes[0,0].set_ylabel('Cumulative Sum')
axes[0,0].grid(True)

axes[0,1].scatter(range(50),data,color='blue',alpha=0.6)
axes[0,1].set_title('Scatter Plot with Random noise')
axes[0,1].set_xlabel('Index')
axes[0,1].set_ylabel('Value')
axes[0,1].grid(True)

axes[1,0].axis('off')
axes[1,1].axis('off')

plt.show()

# %%
import pandas as pd
file_path = "/content/companysales_data.csv"
dataset = pd.read_csv(file_path)
print(dataset.head())




plt.figure(figsize=(10,8))
sns.lineplot(data=dataset,x='month_number',y='total_profit',marker='o',color='blue')
plt.title('Total Profit per Month')
plt.xlabel('Month Number')
plt.ylabel('Total Profit')
plt.grid(True)
plt.show()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-235e6ae2-85db-4443-9a18-6639b0a57433" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-235e6ae2-85db-4443-9a18-6639b0a57433">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
plt.figure(figsize=(12,8))
productcol = dataset.columns[1:6]
for product in productcol:
    sns.lineplot(data=dataset,x='month_number',y=product,marker='o',label=product)

plt.title('Product Sales/Month')
plt.xlabel('Month')
plt.ylabel('Sales')
plt.legend(title='Products')
plt.grid(True)
plt.show()

# %%
data_sum = dataset.sum()
plt.figure(figsize=(13,6))
sns.barplot(x=data_sum.index,y=data_sum.values,palette='viridis')
plt.title('Sum of each attribute')
plt.xlabel('Attributes')
plt.ylabel('Sum')
plt.xticks(rotation=30)
plt.grid(axis='y',linestyle='--',alpha=0.7)
plt.show()
# Out:
# <ipython-input-26-23f196e7a832>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=data_sum.index,y=data_sum.values,palette='viridis')
